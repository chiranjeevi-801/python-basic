# %% [markdown]
# ## What is Inheritance?
#
# ### Inheritance means one class acquires the properties and methods of another class.
#
# Simple Definition :--
#
# ### Inheritance allows one class (child class) to use the properties and methods of another class (parent class).
#
# It helps reuse code instead of writing the same code again.

# %% [markdown]
# # Types of Inheritance

# %% [markdown]
# ##  1. Single Inheritance :--
#
#   #### One parent and one child.
#
#           Animal
#             ↑
#            Dog

# %% [markdown]
# ## 2. Multiple Inheritance :--
#
# ### One child inherits from multiple parents.
#
#
#    Father      Mother
#
#       \     /
#        Child

# %% [markdown]
# ## 3. Multilevel Inheritance

# %% [markdown]
# Grandparent → Parent → Child

# %% [markdown]
#  Animal
#
#        ↑
#
#   Mammal
#
#        ↑
#
#   Dog
#
#
#
#
#
#  # (or)
#
#
#
#
#
#
#  Grand father
#
#      ↑
#
#  father
#
#      ↑
#
#   son

# %% [markdown]
# ## 4. Hierarchical Inheritance

# %% [markdown]
# ### One parent has multiple children.
#
#
#
#
#        Animal
#       /      \
#     Dog      Cat
#
#
#
# ## (OR)
#
#
#        Father
#       /      \
#  child-1     Child-2

# %% [markdown]
# ## 5. Hybrid Inheritance

# %% [markdown]
# ### Hybrid inheritance is a combination of two or more types of inheritance (for example, multiple + multilevel).

# %% [markdown]
#         Animal
#        /      \
#     Mammal   Bird
#         \     /
#          Bat

# %% [markdown]
# Single       : 1 Parent → 1 Child
#
# Multilevel   : Grandfather → Father → Son
#
# Multiple     : 2 Parents → 1 Child
#
# Hierarchical : 1 Parent → Many Children
#
# Hybrid       : Mix of the above

# %% [markdown]
# # 1) Single Inheritance
#
# Definition: One child class inherits from one parent class.

# %%
class Father:
    def prop1(self):
        print("father's property")
class Son:
    def prop2(self):
        print("Son's property")
        
f = Father()
f.prop1()
s= Son()
s.prop2()
# Out:
# father's property
# Son's property

# %%
class Father:
    def prop1(self):
        print("father's property")
class Son(Father):
    def prop2(self):
        print("Son's property")
        
# f = Father()
# f.prop1()
s= Son()
s.prop2()
s.prop1()
# Out:
# Son's property
# father's property

# %%
class Father:
    def prop1(self):
        print("father's property")
class Son:
    def prop2(self):
        print("Son's property")
        
f = Father()
f.prop1()
s= Son()
s.prop2()
# Out:
# father's property
# Son's property

# %% [markdown]
# # 2. Multilevel Inheritance
#
# Definition: A child inherits from a parent, and another child inherits from that child.

# %%
class GFather:
    def prop1(self):
        print("Grand father's property")
class Father(GFather):
    def prop2(self):
        print("Father's property")
class Son(Father):
    def prop3(self):
        print("son's property")
        
s= Son()
s.prop3()
s.prop2()
s.prop1()
# Out:
# son's property
# Father's property
# Grand father's property

# %%
class GFather:
    def prop1(self):
        print("Grandfather's property")

class Father(GFather):
    def prop2(self):
        print("Father's property")

class Son(Father):
    def prop3(self):
        print("Son's property")

s = Son()

s.prop1()
s.prop2()
s.prop3()
# Out:
# Grandfather's property
# Father's property
# Son's property

# %% [markdown]
# # 3. Multiple Inheritance
#
# Definition: One child class inherits from two or more parent classes.

# %%
class Father:
    def prop1(self):
        print("Father's property")

class Mother:
    def prop2(self):
        print("Mother's property")

class Son(Father, Mother):
    def prop3(self):
        print("Son's property")

s = Son()

s.prop1()
s.prop2()
s.prop3()
# Out:
# Father's property
# Mother's property
# Son's property

# %% [markdown]
# # 4. Hierarchical Inheritance
# Definition: One parent class has multiple child classes.

# %%
class Father:
    def prop1(self):
        print("Father's property")

class Son(Father):
    def prop2(self):
        print("Son's property")

class Daughter(Father):
    def prop3(self):
        print("Daughter's property")

s = Son()
d = Daughter()

s.prop1()
s.prop2()

d.prop1()
d.prop3()
# Out:
# Father's property
# Son's property
# Father's property
# Daughter's property

# %% [markdown]
# # 5. Hybrid Inheritance
#
# Definition: Hybrid inheritance is a combination of two or more inheritance types.
#
# Example: Multilevel + Multiple

# %%
class GFather:
    def prop1(self):
        print("Grandfather's property")

class Father(GFather):
    def prop2(self):
        print("Father's property")

class Mother:
    def prop3(self):
        print("Mother's property")

class Son(Father, Mother):
    def prop4(self):
        print("Son's property")

s = Son()

s.prop1()
s.prop2()
s.prop3()
s.prop4()
# Out:
# Grandfather's property
# Father's property
# Mother's property
# Son's property

# %% [markdown]
# ### Easy Memory Trick
#
# Class → Blueprint (Car design)
#
# Object → Real car
#
# Inheritance → Child gets features from Parent
#
# Single → 1 Parent → 1 Child
#
# Multiple → Many Parents → 1 Child
#
# Multilevel → Grandparent → Parent → Child
#
# Hierarchical → 1 Parent → Many Children
#
# Hybrid → Combination of inheritance types

# %% [markdown]
# Write a Python program to implement abstraction using the abc module. Create an abstract class Vehicle and demonstrate how different vehicles (Car, Bike, and Scooty) implement the abstract method start() differently.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass


class Car(Vehicle):

    def start(self):
        print("Car starts with a Key.")


class Bike(Vehicle):

    def start(self):
        print("Bike starts with a Kick.")


class Scooty(Vehicle):

    def start(self):
        print("Scooty starts with Self Start.")



c = Car()
b = Bike()
s = Scooty()


c.start()
b.start()
s.start()
# Out:
# Car starts with a Key.
# Bike starts with a Kick.
# Scooty starts with Self Start.

# %% [markdown]
# Create an abstract class Vehicle with the methods start() and tyres(). Derive the classes Car, Bike, and Scooty, implement the methods, create objects, and display the output.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def tyres(self):
        pass


class Car(Vehicle):

    def start(self):
        print("Car starts with a Key.")

    def tyres(self):
        print("Car has 4 tyres.")


class Bike(Vehicle):

    def start(self):
        print("Bike starts with a Kick.")

    def tyres(self):
        print("Bike has 2 tyres.")


class Scooty(Vehicle):

    def start(self):
        print("Scooty starts with Self Start.")

    def tyres(self):
        print("Scooty has 2 tyres.")


c = Car()
b = Bike()
s = Scooty()

print(" Car ")
c.start()
c.tyres()

print("\n Bike ")
b.start()
b.tyres()

print("\n Scooty ")
s.start()
s.tyres()
# Out:
#  Car
# Car starts with a Key.
# Car has 4 tyres.
#
#  Bike
# Bike starts with a Kick.
# Bike has 2 tyres.
#
#  Scooty
# Scooty starts with Self Start.
# Scooty has 2 tyres.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def tyres(self):
        pass


class Car(Vehicle):
    def start(self):
        print("Car starts with Key")

    def tyres(self):
        print("number of 4 tyres")


class Bike(Vehicle):
    def start(self):
        print("Bike starts with Kick")

    def tyres(self):
        print("number of 2 tyres")


class Scooty(Vehicle):
    def start(self):
        print("Scooty starts with Self Start")

    def tyres(self):
        print("number 2 tyres")


for vehicle in [Car(), Bike(), Scooty()]:
    vehicle.start()
    vehicle.tyres()
    print()
# Out:
# Car starts with Key
# number of 4 tyres
#
# Bike starts with Kick
# number of 2 tyres
#
# Scooty starts with Self Start
# number 2 tyres

# %% [markdown]
#  ## example : Person → Student

# %%
class Person:
    def show(self):
        print("I am a Person")

class Student(Person):
    def study(self):
        print("I am Studying")

s = Student()
s.show()
s.study()
# Out:
# I am a Person
# I am Studying

# %% [markdown]
# ## Example: Vehicle → Car

# %%
class Vehicle:
    def fuel(self):
        print("Vehicle uses Fuel")

class Car(Vehicle):
    def drive(self):
        print("Car is Driving")

c = Car()
c.fuel()
c.drive()
# Out:
# Vehicle uses Fuel
# Car is Driving

# %% [markdown]
# ## Example: Fruit → Mango

# %%
class Fruit:
    def taste(self):
        print("Fruits are Sweet")

class Mango(Fruit):
    def color(self):
        print("Mango is Yellow")

m = Mango()
m.taste()
m.color()
# Out:
# Fruits are Sweet
# Mango is Yellow
